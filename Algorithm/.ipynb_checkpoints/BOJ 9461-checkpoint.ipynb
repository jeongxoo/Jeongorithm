# %% [markdown]
# # 9461
#
# 오른쪽 그림과 같이 삼각형이 나선 모양으로 놓여져 있다.
#
# 첫 삼각형은 정삼각형으로 변의 길이는 1이다.
#
# 그 다음에는 다음과 같은 과정으로 정삼각형을 계속 추가한다.
#
# 나선에서 가장 긴 변의 길이를 k라 했을 때, 그 변에 길이가 k인 정삼각형을 추가한다.
#
# 파도반 수열 P(N)은 나선에 있는 정삼각형의 변의 길이이다.
#
# P(1)부터 P(10)까지 첫 10개 숫자는 1, 1, 1, 2, 2, 3, 4, 5, 7, 9이다.
#
# N이 주어졌을 때, P(N)을 구하는 프로그램을 작성하시오.
#
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202021-10-14%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%201.32.42.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202021-10-14%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%201.32.42.png)

# %% [markdown]
# ## 입력
#
# 첫째 줄에 테스트 케이스의 개수 T가 주어진다.
#
# 각 테스트 케이스는 한 줄로 이루어져 있고, N이 주어진다. (1 ≤ N ≤ 100)
#
#
# ## 출력
#
# 각 테스트 케이스마다 P(N)을 출력한다.
#
#
# 입력
# - 2
# - 6
# - 12
#
# 출력
# - 3
# - 16

# %%
# 쓴건 버려는 형태로 가면되나?

from collections import deque

def wave():
    ans = lengths.popleft() + lengths.pop()
    for _ in range(2): lengths.append(ans)
    answers.append(ans)
    
count = int(input())

for i in range(count):
    n = int(input())
    answers = [1,1,1,2,2]
    lengths = deque([1,1,1,2,2,2])
    
    if n <= 5: 
        print(answers[n-1])
        continue
    else:    
        for _ in range(n - 5): wave()

    print(answers[-1])
# Out:
# 2
# 6
# 3
# 12
# 16

# %%
lengths
# Out:
# deque([1, 1, 2, 2, 3, 3])

# %%
answers
# Out:
# [1, 1, 2, 2, 3]
